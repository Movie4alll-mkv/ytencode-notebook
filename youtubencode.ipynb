# %%
# !pip install telethon
# !pip install python-decouple
# !pip install psutil
# !pip install speedtest-cli
# !pip install https://github.com/1Danish-00/Telethon/archive/master.zip
# !apt-get install python2
# !pip install html_telegraph_poster
# !apt -qq update && apt -qq install -y git wget pv jq python3-dev ffmpeg mediainfo
# !git clone https://github.com/XniceCraft/ffmpeg-colab --depth 1
# !chmod +x ./ffmpeg-colab/install
# !./ffmpeg-colab/install
# !git clone https://github.com/Movie4alll-mkv/youtube && cd youtube && bash run.sh
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 564.0/564.0 kB 8.8 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for telethon: filename=Telethon-1.32.1-py3-none-any.whl size=635330 sha256=c4a4f0541b402f7d6c2d05bf987aef49ad0010cda28920da2812080044105161
#   Stored in directory: /root/.cache/pip/wheels/f0/7d/c3/0408a88fecf9658fb4f505f2f47f7885b435e7161029f3060f
# ...
#   Created wheel for pyaes: filename=pyaes-1.6.1-py3-none-any.whl size=26348 sha256=72a723753fd5dfac542f66e21006d6a620178264274e6d718d26a646a6399bd2
#   Stored in directory: /root/.cache/pip/wheels/d6/84/5f/ea6aef85a93c7e1922486369874f4740a5642d261e09c59140
# Successfully built telethon pyaes
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 546.1/546.1 kB 11.8 MB/s eta 0:00:00
#   Installing build dependencies ... done
# ...

# %%
# !apt -qq update && apt -qq install -y git wget pv jq python3-dev ffmpeg mediainfo

# %%
# !pip3 install -r requirements.txt

# %%
# !pip install wheel
# !pip install youtube-dl

# %%
# !pip install aiohttp

# %%
# !git clone https://github.com/XniceCraft/ffmpeg-colab --depth 1
# !chmod +x ./ffmpeg-colab/install
# !./ffmpeg-colab/install
# !bash run.sh
